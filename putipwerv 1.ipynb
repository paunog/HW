# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %%
PAULO MENEZES NOGUEIRA
BUSINESS MANAGER and consultant / Data Scientist

# %% [markdown]
# I´m interested in data science because of the value that data has for business decisions to my work. I hope to use data scioence tools for preparation and organizxation of data, analysis and modeing and forectas in a more efective and effcinet way.

# %% [markdown]
# my code should calcule the value of a series with a factor of 2 (100%)

# %%
def series (x):
    return (x*2)
series (2) == sum (range (2))
# Out:
# False

# %% [markdown]
# .five
# .six
# .seven
# .eight
# .nine
#
# _______________
# A   B   C   D
# 1   2   3   4
# 2   2   3   3
